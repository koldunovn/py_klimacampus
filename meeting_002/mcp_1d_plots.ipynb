# %%
import mcp
import numpy as np
import ferr

# %%
reload(mcp)
# Out:
# <module 'mcp' from 'mcp.pyc'>

# %%
# %matplotlib inline

# %% [markdown]
# NCEP reanalysis, monthly air temperatures

# %%
#!wget ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis.derived/surface/air.mon.mean.nc

# %%
data = ferr.use('air.mon.mean.nc')
# Out:
# AIR:  time (801 , tax ) :  lat (73 , yax ) :  lon (144 , xax ) :
#
# long_name: Monthly Mean Air Temperature at sigma level 0.995 ::  valid_range: [-2000.  2000.] ::  units: degC ::  add_offset: 0.0 ::  scale_factor: 1.0 ::  missing_value: -9.96921e+36 ::  precision: 1 ::  least_significant_digit: 0 ::  var_desc: Air Temperature ::  dataset: CDC Derived NCEP Reanalysis Products ::  level_desc: Surface ::  statistic: Mean ::  parent_stat: Individual Obs ::  actual_range: [-73.78000641  41.74901962] ::

# %%
air = data.gv('air')

# %%
mcp.shade(air.x, air.y, air[1,:,:]);

# %% [markdown]
# Calculate global mean for every month

# %%
global_mt = air.mean(axis=1).mean(axis=1)

# %% [markdown]
# Due to bug in numpy.nanmin in numpy 1.6.0 I have to unmask global_mt:
#
#         np.ma.filled(global_mt)

# %% [markdown]
# Standard plot with pylab plot

# %%
plot(air.t, np.ma.filled(global_mt))

# %% [markdown]
# Plot with mcp plot1

# %%
mcp.plot1(air.t, np.ma.filled(global_mt))

# %% [markdown]
# With mcp dateplot1

# %%
mcp.dateplt1(air.t, np.ma.filled(global_mt))

# %%
mcp.dateplt_m2(air.t, np.ma.filled(global_mt), ticksize=15)

# %%
mcp.dateplt_m2(air.t, np.ma.filled(global_mt), ticksize=10)

# %%
mcp.longts(air.t, np.ma.filled(global_mt), ticksize=10)

# %%
mcp.barplt1(air.t[0:48], np.ma.filled(global_mt)[0:48], width=10)

# %%
F,P,Rcmp = mcp.fftplt1(np.ma.filled(global_mt), Mch=256)

# %%
F,P,Rcmp = mcp.fftplt2(np.ma.filled(global_mt), Mch=256, 
pval=0.2, titlestr='Hi, Mark')

# %%
F,P,Rcmp = mcp.fftplt3(np.ma.filled(global_mt), Mch=256, 
pval=0.8, titlestr='Hi, Mark')
