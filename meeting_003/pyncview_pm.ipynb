# %% [markdown]
# # Python Version of ncview in 3 Lines of Code

# %% [markdown]
# This is demonstration of IPython notebook functionality that is avalible since version 2.0. **It will work only in IPython >= 2.0**.

# %%
from netCDF4 import Dataset, num2date, date2num
from IPython.html.widgets import *
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['Widget', 'date2num', 'num2date', 'interactive']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
x=linspace(0,1,100)
f=2

# %%
plot(x,sin(2*pi*x*f))

# %%
def pltsin(f):
    plot(x,sin(2*pi*x*f))

# %%
pltsin(5)

# %%
interact(pltsin, f=(1,10,0.1))

# %%
def pltsin(f, a):
    plot(x,a*sin(2*pi*x*f))
    ylim(-10,10)

# %%
interact(pltsin, f=(1,10,0.1), a=(1,10,1));

# %% [markdown]
# Doenload netCDF data

# %%
variabs = ['air', 'uwnd', 'vwnd', 'rhum']
for vvv in variabs:
    for i in range(2000,2010):
        # !wget ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis.dailyavgs/surface/{vvv}.sig995.{i}.nc
# Out:
# --2014-06-03 17:22:31--  ftp://ftp.cdc.noaa.gov/Datasets/ncep.reanalysis.dailyavgs/surface/air.sig995.2000.nc
#            => `air.sig995.2000.nc.1'
# Resolving ftp.cdc.noaa.gov (ftp.cdc.noaa.gov)...
# 140.172.38.117
# Connecting to ftp.cdc.noaa.gov (ftp.cdc.noaa.gov)|140.172.38.117|:21...
# connected.
# Logging in as anonymous ...
# Logged in!
# ==> SYST ...
# done.    ==> PWD ...
# done.
# ==> TYPE I ...
# done.  ==> CWD (1) /Datasets/ncep.reanalysis.dailyavgs/surface ...
# done.
# ==> SIZE air.sig995.2000.nc ...
# 7700340
# ==> PASV ...
# done.    ==> RETR air.sig995.2000.nc ...
# done.
# Length: 7700340 (7.3M) (unauthoritative)
#
#  0% [                                       ] 0           --.-K/s
#  0% [                                       ] 15,048      71.6K/s
#  1% [                                       ] 77,976       181K/s
#  1% [                                       ] 127,224      158K/s
#  2% [                                       ] 195,624      194K/s
#  2% [>                                      ] 197,976      157K/s
#  3% [>                                      ] 297,840      204K/s
#  4% [>                                      ] 356,664      213K/s
#  5% [=>                                     ] 419,592      205K/s
#  6% [=>                                     ] 482,520      214K/s
#  7% [=>                                     ] 548,184      223K/s
#  8% [==>                                    ] 616,584      231K/s
#  8% [==>                                    ] 687,720      239K/s
#  9% [==>                                    ] 762,960      247K/s  eta 27s
# 11% [===>                                   ] 895,656      272K/s  eta 27s
# 12% [====>                                  ] 999,624      285K/s  eta 27s
# 14% [====>                                  ] 1,092,648    284K/s  eta 27s
# 15% [=====>                                 ] 1,185,672    292K/s  eta 27s
# 16% [=====>                                 ] 1,284,168    313K/s  eta 21s
# 17% [======>                                ] 1,385,400    328K/s  eta 21s
# 19% [======>                                ] 1,492,104    346K/s  eta 21s
# 20% [=======>                               ] 1,604,280    361K/s  eta 21s
# 22% [=======>                               ] 1,721,928    376K/s  eta 21s
# 23% [========>                              ] 1,845,048    406K/s  eta 16s
# 25% [========>                              ] 1,973,640    421K/s  eta 16s
# 28% [=========>                             ] 2,159,688    453K/s  eta 16s
# 30% [==========>                            ] 2,355,312    488K/s  eta 16s
# 33% [===========>                           ] 2,553,672    517K/s  eta 16s
# 35% [============>                          ] 2,715,096    541K/s  eta 12s
# 38% [=============>                         ] 2,939,448    580K/s  eta 12s

# %% [markdown]
# Simplest case:

# %%
f = Dataset('air.sig995.2000.nc')

# %%
air = f.variables['air']

# %%
imshow(air[0,:,:])

# %% [markdown]
# Different times

# %%
def sh(time):
    imshow(air[time,:,:])

# %%
sh(0)

# %%
interact(sh, time=(0,355,1));

# %% [markdown]
# Add different variables:

# %%
def sh(var='air', time=0):
    f = Dataset(var+'.sig995.2000.nc')
    vv = f.variables[var]
    imshow(vv[time,:,:])

# %%
variabs = ['air', 'uwnd', 'vwnd', 'rhum']

# %%
interact(sh, time=(0,355,1), var=variabs);

# %%
def sh(year='2000',var='air', time=0):
    f = Dataset(var+'.sig995.'+year+'.nc')
    vv = f.variables[var]
    imshow(vv[time,:,:])

# %%
years = [str(x) for x in range(2000,2010)]

# %%
interact(sh, year=years, time=(0,355,1), var=variabs);

# %%
def sh(year='2000',var='air', FixedColor=False, vm=-3., vma=0., time=0):
    f = Dataset(var+'.sig995.'+year+'.nc')
    vv = f.variables[var]
    if FixedColor==False:
        imshow(vv[time,:,:])
        colorbar()
    else:
        imshow(vv[time,:,:], vmin=vm, vmax=vma)
        colorbar()

# %%
interact(sh, year=years, time=(0,355,1), var=variabs,\
         vm=FloatTextWidget(value=250), vma=FloatTextWidget(value=300));

# %%
from mpl_toolkits.basemap import Basemap

# %%
m = Basemap(projection='npstere',boundinglat=60,lon_0=0,resolution='l')

# %%
lon = f.variables['lon'][:]
lat = f.variables['lat'][:]
lon, lat = np.meshgrid(lon, lat)
x, y = m(lon, lat)

# %%
def sh(year='2000',var='air', FixedColor=False, vm=-3., vma=0., inte=10, time=0):
    f = Dataset(var+'.sig995.'+year+'.nc')
    vv = f.variables[var]
    tt = f.variables['time']
    dd = num2date(tt[time], tt.units)
    if FixedColor==False:
        m.fillcontinents(color='gray',lake_color='gray')
        m.drawparallels(np.arange(-80.,81.,20.))
        m.drawmeridians(np.arange(-180.,181.,20.))
        m.drawmapboundary(fill_color='white')
        cs = m.contourf(x,y,vv[time,:,:]-273.15)
        #imshow(vv[time,:,:])
        colorbar()
        title(str(dd))
        
    else:
        m.fillcontinents(color='gray',lake_color='gray')
        m.drawparallels(np.arange(-80.,81.,20.))
        m.drawmeridians(np.arange(-180.,181.,20.))
        m.drawmapboundary(fill_color='white')
        cs = m.contourf(x,y,vv[time,:,:]-273.15, levels = linspace(vm,vma,inte))
        #imshow(vv[time,:,:])
        colorbar()
        title(str(dd))

# %%
interact(sh, year=years, time=(0,355,1), var=variabs,\
         vm=FloatTextWidget(value=250), vma=FloatTextWidget(value=300), inte=FloatTextWidget(value=10));
